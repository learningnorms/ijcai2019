# %% [markdown]
# # Performance on Expt. '606

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_raw = pd.read_csv('simulation/Experiment2018-08-28T13:55:51.606.csv')

# %%
df_raw.head()
# Out:
#    numActors  numObservers  numNorms  flatness  lifetime  sanctionRate  \
# 0        100             1         5       0.1        25           0.1
# 1        100             1         5       0.1        25           0.1
# 2        100             1         5       0.1        25           0.1
# 3        100             1         5       0.1        25           0.1
# 4        100             1         5       0.1        25           0.1
#
#    probIgnorance  propMissing  sensorReliability           masterSeed  ff  fp  \
# 0            0.1          0.1               0.50 -2761553798939175148   0   1
# 1            0.1          0.1               0.99 -2761553798939175148   0   1
# 2            0.1          0.9               0.50 -2761553798939175148   1   0
# 3            0.1          0.9               0.99 -2761553798939175148   1   0
# 4            0.9          0.1               0.50 -2761553798939175148   1   0
#
#    fo  pf  pp  po  of  op  oo  sizeFocalSet
# 0   0   1   1   0   1   1   0            15
# 1   0   1   1   0   1   1   0            14
# 2   0   0   2   0   1   1   0            15
# 3   0   1   1   0   0   2   0            14
# 4   0   1   1   0   1   1   0            19

# %%
# Sum (and average for focal set size) over all seeds
df = df_raw.groupby(['numActors','numObservers','numNorms','flatness',
                         'lifetime','sanctionRate','probIgnorance','propMissing',
                         'sensorReliability']).agg({'ff' : 'sum', 'fp': 'sum', 'fo' : 'sum', 'pf': 'sum',
                                                   'pp' : 'sum', 'po' : 'sum', 'of' : 'sum', 'op' : 'sum',
                                                   'oo' : 'sum', 'sizeFocalSet' : 'mean'}).reset_index()

# Get some stats about the data collected
numForbidden = df.ff.sum() + df.fo.sum() + df.fp.sum()
numObligatory = df.of.sum() + df.op.sum() + df.oo.sum()
numOptional = df.pf.sum() + df.pp.sum() + df.po.sum()
print("Overall distribution of Norms hybrid (F,Op,O):", numForbidden,numOptional,numObligatory)

df.head()
# Out:
# Overall distribution of Norms hybrid (F,Op,O): 209152 217088 213760
#    numActors  numObservers  numNorms  flatness  lifetime  sanctionRate  \
# 0        100             1         5       0.1        25           0.1
# 1        100             1         5       0.1        25           0.1
# 2        100             1         5       0.1        25           0.1
# 3        100             1         5       0.1        25           0.1
# 4        100             1         5       0.1        25           0.1
#
#    probIgnorance  propMissing  sensorReliability    ff   fp  fo    pf   pp  \
# 0            0.1          0.1               0.50  1135  499   0  1055  641
# 1            0.1          0.1               0.99  1277  357   0  1148  548
# 2            0.1          0.9               0.50  1089  545   0   977  719
# 3            0.1          0.9               0.99  1239  394   1  1152  544
# 4            0.9          0.1               0.50  1104  530   0  1006  690
#
#    po   of    op  oo  sizeFocalSet
# 0   0  575  1091   4        14.308
# 1   0  735   931   4        14.419
# 2   0  557  1109   4        14.370
# 3   0  705   962   3        14.325
# 4   0  598  1069   3        18.762

# %%
df.shape
# Out:
# (128, 19)

# %%
# Let's combine the probIgnorance and PropMissing
# First, let's  add a new column that multiplies probIg * propMissing

df = df.assign(ambiguity = lambda x: x.probIgnorance * x.propMissing )
df.head()
# Out:
#    numActors  numObservers  numNorms  flatness  lifetime  sanctionRate  \
# 0        100             1         5       0.1        25           0.1
# 1        100             1         5       0.1        25           0.1
# 2        100             1         5       0.1        25           0.1
# 3        100             1         5       0.1        25           0.1
# 4        100             1         5       0.1        25           0.1
#
#    probIgnorance  propMissing  sensorReliability    ff   fp  fo    pf   pp  \
# 0            0.1          0.1               0.50  1135  499   0  1055  641
# 1            0.1          0.1               0.99  1277  357   0  1148  548
# 2            0.1          0.9               0.50  1089  545   0   977  719
# 3            0.1          0.9               0.99  1239  394   1  1152  544
# 4            0.9          0.1               0.50  1104  530   0  1006  690
#
#    po   of    op  oo  sizeFocalSet  ambiguity
# 0   0  575  1091   4        14.308       0.01
# 1   0  735   931   4        14.419       0.01
# 2   0  557  1109   4        14.370       0.09
# 3   0  705   962   3        14.325       0.09
# 4   0  598  1069   3        18.762       0.09

# %%
# Then let's remove the probIg and propMis
df = df.drop(columns=['probIgnorance', 'propMissing'])
df.head()
# Out:
#    numActors  numObservers  numNorms  flatness  lifetime  sanctionRate  \
# 0        100             1         5       0.1        25           0.1
# 1        100             1         5       0.1        25           0.1
# 2        100             1         5       0.1        25           0.1
# 3        100             1         5       0.1        25           0.1
# 4        100             1         5       0.1        25           0.1
#
#    sensorReliability    ff   fp  fo    pf   pp  po   of    op  oo  \
# 0               0.50  1135  499   0  1055  641   0  575  1091   4
# 1               0.99  1277  357   0  1148  548   0  735   931   4
# 2               0.50  1089  545   0   977  719   0  557  1109   4
# 3               0.99  1239  394   1  1152  544   0  705   962   3
# 4               0.50  1104  530   0  1006  690   0  598  1069   3
#
#    sizeFocalSet  ambiguity
# 0        14.308       0.01
# 1        14.419       0.01
# 2        14.370       0.09
# 3        14.325       0.09
# 4        18.762       0.09

# %%
df.shape
# Out:
# (128, 18)

# %%
# Group by ambiguity
# Now lets have ambiguity only take on two values (set 0.01 value to 0.09)
df.loc[df['ambiguity'] < 0.1, 'ambiguity'] = 0.1
df.loc[df['ambiguity'] > 0.1, 'ambiguity'] = 0.9

# Sum (and average for focal set size) over all variables including the newly added ambiguity
df_am = df.groupby(['numActors','numObservers','numNorms','flatness',
                         'lifetime','sanctionRate',
                         'sensorReliability','ambiguity']).agg({'ff' : 'sum', 'fp': 'sum', 'fo' : 'sum', 'pf': 'sum',
                                                   'pp' : 'sum', 'po' : 'sum', 'of' : 'sum', 'op' : 'sum',
                                                   'oo' : 'sum', 'sizeFocalSet' : 'mean'}).reset_index()
df_am.head()
# Out:
#    numActors  numObservers  numNorms  flatness  lifetime  sanctionRate  \
# 0        100             1         5       0.1        25           0.1
# 1        100             1         5       0.1        25           0.1
# 2        100             1         5       0.1        25           0.1
# 3        100             1         5       0.1        25           0.1
# 4        100             1         5       0.1        25           1.0
#
#    sensorReliability  ambiguity    ff    fp  fo    pf    pp  po    of    op  \
# 0               0.50        0.1  3328  1574   0  3038  2050   0  1730  3269
# 1               0.50        0.9   243  1391   0   192  1504   0    96  1572
# 2               0.99        0.1  3720  1181   1  3442  1645   1  2158  2841
# 3               0.99        0.9   429  1205   0   353  1343   0   190  1477
# 4               0.50        0.1  4902     0   0  1677  3411   0     0     0
#
#      oo  sizeFocalSet
# 0    11     15.813333
# 1     2     16.072000
# 2    11     15.867000
# 3     3     16.052000
# 4  5010      7.275000

# %%
df_am.shape
# Out:
# (64, 18)

# %%
# summing over lifetimes. That is, grouping by everything else

df_am = df_am.groupby(['numActors','numObservers','numNorms','flatness',
                         'sanctionRate',
                         'sensorReliability','ambiguity']).agg({'ff' : 'sum', 'fp': 'sum', 'fo' : 'sum', 'pf': 'sum',
                                                   'pp' : 'sum', 'po' : 'sum', 'of' : 'sum', 'op' : 'sum',
                                                   'oo' : 'sum', 'sizeFocalSet' : 'mean'}).reset_index()

# %%
df_am.shape
df_am.head()
# Out:
#    numActors  numObservers  numNorms  flatness  sanctionRate  \
# 0        100             1         5       0.1           0.1
# 1        100             1         5       0.1           0.1
# 2        100             1         5       0.1           0.1
# 3        100             1         5       0.1           0.1
# 4        100             1         5       0.1           1.0
#
#    sensorReliability  ambiguity     ff    fp  fo     pf     pp  po    of  \
# 0               0.50        0.1  14145  5463   0  12337   8015   0  5500
# 1               0.50        0.9    577  5959   0    411   6373   0   164
# 2               0.99        0.1  15530  4077   1  13889   6462   1  7181
# 3               0.99        0.9   1019  5517   0    769   6015   0   328
# 4               0.50        0.1  19606     2   0   4867  15485   0     0
#
#       op     oo  sizeFocalSet
# 0  14529     11     35.023917
# 1   6514      2     36.341250
# 2  12844     15     35.079583
# 3   6348      4     36.266250
# 4      0  20040     13.210500

# %%
df_am.head()
# Out:
#    numActors  numObservers  numNorms  flatness  sanctionRate  \
# 0        100             1         5       0.1           0.1
# 1        100             1         5       0.1           0.1
# 2        100             1         5       0.1           0.1
# 3        100             1         5       0.1           0.1
# 4        100             1         5       0.1           1.0
#
#    sensorReliability  ambiguity     ff    fp  fo     pf     pp  po    of  \
# 0               0.50        0.1  14145  5463   0  12337   8015   0  5500
# 1               0.50        0.9    577  5959   0    411   6373   0   164
# 2               0.99        0.1  15530  4077   1  13889   6462   1  7181
# 3               0.99        0.9   1019  5517   0    769   6015   0   328
# 4               0.50        0.1  19606     2   0   4867  15485   0     0
#
#       op     oo  sizeFocalSet
# 0  14529     11     35.023917
# 1   6514      2     36.341250
# 2  12844     15     35.079583
# 3   6348      4     36.266250
# 4      0  20040     13.210500

# %%
df_am.shape
# Out:
# (16, 17)

# %%
# Let's do precision and recall on this
# df_p = df performance measures
df_am = df_am.assign(pre_f = lambda x: x.ff/(x.ff + x.pf + x.of) )
df_am = df_am.assign(rec_f = lambda x: x.ff/(x.ff + x.fp + x.fo) )
df_am = df_am.assign(pre_o = lambda x: x.oo/(x.fo + x.po + x.oo) )
df_am = df_am.assign(rec_o = lambda x: x.oo/(x.of + x.op + x.oo) )

# %%
df_am.head()
# Out:
#    numActors  numObservers  numNorms  flatness  sanctionRate  \
# 0        100             1         5       0.1           0.1
# 1        100             1         5       0.1           0.1
# 2        100             1         5       0.1           0.1
# 3        100             1         5       0.1           0.1
# 4        100             1         5       0.1           1.0
#
#    sensorReliability  ambiguity     ff    fp  fo    ...        pp  po    of  \
# 0               0.50        0.1  14145  5463   0    ...      8015   0  5500
# 1               0.50        0.9    577  5959   0    ...      6373   0   164
# 2               0.99        0.1  15530  4077   1    ...      6462   1  7181
# 3               0.99        0.9   1019  5517   0    ...      6015   0   328
# 4               0.50        0.1  19606     2   0    ...     15485   0     0
#
#       op     oo  sizeFocalSet     pre_f     rec_f     pre_o     rec_o
# 0  14529     11     35.023917  0.442280  0.721389  1.000000  0.000549
# 1   6514      2     36.341250  0.500868  0.088280  1.000000  0.000299
# 2  12844     15     35.079583  0.424317  0.792024  0.882353  0.000749
# 3   6348      4     36.266250  0.481569  0.155906  1.000000  0.000599
# 4      0  20040     13.210500  0.801128  0.999898  1.000000  1.000000
#
# [5 rows x 21 columns]

# %%
df_am.to_csv('out.csv')

# %%
df_am.shape
# Out:
# (16, 21)
